# %%
import os

os.environ["LANGSMITH_TRACING_V2"] = "true"
os.environ["LANGSMITH_API_KEY"] = "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"
os.environ["mistral_api_key"] = 'Eajkd7toYyYCEoU1LQiNFcPTvyK3ONep'
os.environ["LANGSMITH_PROJECT"] = "llm_rag"

# %%
# LANGSMITH_TRACING='true'
# LANGSMITH_ENDPOINT="https://api.smith.langchain.com"
# LANGSMITH_API_KEY= "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"
# LANGSMITH_PROJECT="my_langsmith"
# # OPENAI_API_KEY="<your-openai-api-key>"

# %%
from langchain_mistralai.chat_models import ChatMistralAI
llm = ChatMistralAI(api_key='Eajkd7toYyYCEoU1LQiNFcPTvyK3ONep')
llm.invoke("Hello, world!")
# Out:
# AIMessage(content='Hello! I\'m here to help you with any questions you have about programming or technology. Is there something specific you\'d like to know?\n\nFor example, I can explain the meaning of the phrase "Hello, world!" in the context of programming. "Hello, world!" is often the first program that people write when they are learning a new programming language. It is a simple program that, when run, prints the string "Hello, world!" to the console. This program is used to introduce basic concepts of the programming language, such as syntax and data types.\n\nHere is an example of a "Hello, world!" program in the Python programming language:\n\n```\nprint("Hello, world!")\n```\n\nWhen you run this program, it will print the string "Hello, world!" to the console.\n\nDo you have any other questions about programming or technology? I\'m here to help!', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 12, 'total_tokens': 208, 'completion_tokens': 196}, 'm
# ...
